# %% [markdown]
# # Polynomial Regression

# %%
import pandas as pd
df=pd.read_csv("automobiles.csv")
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
#Visualizing polynomial regression
import matplotlib.pyplot as plt
def plotpolly(model,independent_variable,dependent_variable,name):
    x_new=np.linspace(15,55,100)
    y_new=model(x_new)
    plt.plot(independent_variable,dependent_variable,'.',x_new,y_new,'-')
    plt.title("Polynomial fit with matplotlib for price dif length")
    ax=plt.gca()
    ax.set_facecolor((0.898,0.898,0.898))
    fit=plt.gcf()
    plt.xlabel(name)
    plt.ylabel("Price of cars")
    plt.show()
    plt.close()
#For one independent variable
import numpy as np
X=df["highway-mpg"]
Y=df["price"]
f=np.polyfit(X,Y,3)
print(f)
p=np.poly1d(f)
print(p)
plotpolly(p,X,Y,"highway-mpg")
# Out:
# [-1.55663829e+00  2.04754306e+02 -8.96543312e+03  1.37923594e+05]
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
x_new=np.linspace(15,55,100)
y_new=p(x_new)
plt.plot(X,Y,'.',x_new,y_new,'-')
plt.title("Polynomial fit with matplotlib for price dif length")
ax=plt.gca()
ax.set_facecolor((0.898,0.898,0.898))
fit=plt.gcf()
plt.xlabel("highway-mpg")
plt.ylabel("Price of cars")
plt.show()
plt.close()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=4)
# X_train.head()
Yhat=p(X_test)
Yhat[0:5]
# Out:
# array([13247.51877575, 23210.06482402, 13247.51877575, 19172.71155671,
#        14483.47732607])

# %%
x_new=np.linspace(15,55,100)
y_new=p(x_new)
   
# plt.plot(X,Y,'-',X_test,Yhat,'.')
plt.plot(X,Y,'.',x_new,y_new,'-')
plt.title("Polynomial regression")
ax=plt.gca()
ax.set_facecolor((0.898,0.898,0.898))
fit=plt.gcf()
plt.xlabel("highway-mpg")
plt.ylabel("price")
plt.show()
plt.close()

# %%
plt.plot(X)

# %% [markdown]
# # Visualizing and analysing polynomial regression and working of plot function

# %%
X=df["highway-mpg"]
Y=df["price"]
f=np.polyfit(X,Y,3)#Training the model, degree of polynomial= 3
p=np.poly1d(f)
print("1 ",type(f),"   ",print(type(p)))
print("2 ",print(type(p)),type(f))
print("3 ",type(p))
x_new=np.linspace(15,55,100)
y_new=p(x_new)#Testing the model
# plt.plot(X,Y,'.',x_new,y_new,'-')
# Out:
# <class 'numpy.poly1d'>
# 1  <class 'numpy.ndarray'>     None
# <class 'numpy.poly1d'>
# 2  None <class 'numpy.ndarray'>
# 3  <class 'numpy.poly1d'>
